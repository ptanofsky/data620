# %% [markdown]
# # Week 2 Assignment
# ## Author: Philip Tanofsky
# ### Course: DATA 620 Web Analytics
# ### Due Date: February 13, 2022

# %%
import networkx as net
import matplotlib.pyplot as plot

# %% [markdown]
# ### Approach
# **Textbook:** Social Network Analysis for Startups
#
# Chapter 1 example below reads in a file with nodes and edges defined. Using the Networkx library, the network graph is plotted.

# %%
orgchart=net.read_pajek("ACME_orgchart.net")
net.draw(orgchart, with_labels=True)
#net.draw(orgchart)

# %% [markdown]
# Using the same approach as the textbook, I created a file named "w2assign.net" with the nodes and edges defined to match the Krackhardt kite graph shown in Week 2 assignment. I couldn't quite get the clean shape provided in the handout, but the below graph does match the assignment sample in nodes and edges.

# %%
kite=net.read_pajek("w2assign.net")
# The created file "w2assign.net" is included in the same github directory as this IPython notebook
net.draw(kite, with_labels=True)

# %% [markdown]
# I noticed the Networkx library can automatically generate the Krackhardt Kite, so I've included that code below. As seen below, the graph shape below matches the graph shape above in nodes and edges.

# %%
# Using Networkx build-in graph generator
g = net.generators.small.krackhardt_kite_graph()
net.draw(g)

# %% [markdown]
# ### Notes on Setup
# - Using Networkx version 1.11 (based on provided sps620env.yml file) to match textbook
# - Python error: Using matplotlib v2.2.3 to work with Networkx v1.11
#     - pip install matplotlib==2.2.3
# - Jupyter Lab error: Addressed by installing jupyter_server v1.6.4
#     - pip install jupyter_server==1.6.4

# %%
net.__version__
# Out:
# '1.11'

# %%
import matplotlib as mat
mat.__version__
# Out:
# '2.2.3'

# %%
import jupyter_server as js
js.__version__
# Out:
# '1.6.4'
